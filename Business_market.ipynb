# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
from sklearn.neighbors import BallTree
import pandas as pd
import numpy as np
import gzip
import json

pd.set_option('display.max_columns', None)

def parse(path):
  g = open('Data/' + path, 'r')
  for l in g:
    yield json.loads(l)

def parse_first_n(path, n=10000):
    g = open('Data/' + path, 'r')
    for i, l in enumerate(g):
        if i >= n:
            break
        yield json.loads(l)

# %%
path = 'Data/simplemaps_uscities_basicv1.93/uscities.csv'

us_cities = pd.read_csv(path)

# %% [markdown]
# Use the city column to count the number of companies in the same city.
#
# When a company is compairing cities to locate in they can use aggregate stats such as  ***number of reviews in the city % number of compeditors***

# %% [markdown]
# Need to make a number of compeditors column which will be matched to each (city, category) as well as a number of reviews per city column which will be matched to the city

# %%
#CREATES A QUALITY INDEX SCORE
df["quality_penalty"] = 5 - df["avg_competitor_rating"] #per city, per category --> we already do this
df["opportunity_score"] = df["demand"] * df["quality_penalty"] / df["competition"]
#demand is just the count of the gmap_ids in the category
#competiton is just the count of competitors in the city

# %%
us_cities
# Out:
#               city   city_ascii state_id    state_name  county_fips  \
# 0         New York     New York       NY      New York        36081
# 1      Los Angeles  Los Angeles       CA    California         6037
# 2          Chicago      Chicago       IL      Illinois        17031
# 3            Miami        Miami       FL       Florida        12086
# 4          Houston      Houston       TX         Texas        48201
# ...            ...          ...      ...           ...          ...
# 31252   Santa Cruz   Santa Cruz       AZ       Arizona         4021
# 31253   Frankstown   Frankstown       PA  Pennsylvania        42013
# 31254      Ski Gap      Ski Gap       PA  Pennsylvania        42013
# 31255      Sherman      Sherman       CT   Connecticut         9190
# 31256   Twin Lakes   Twin Lakes       CA    California         6051
#
#                county_name      lat       lng  population  density source  \
# 0                   Queens  40.6943  -73.9249    19268388  10943.7  shape
# ...
