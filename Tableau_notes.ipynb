# %% [markdown]
# Here are some Tableau notes from the videos that I have watched: (Add images later)

# %% [markdown]
# - The Analysis tab at the top allows you to toggle aggregate or individual data display types
# - The drop down for a element that you want to make geographical will allow you to use Tableau's prexisiting datasets to add location values to your data.
# - **If you go again to the upper menu and click on map, it allows you to change the style as well as LAYERS which give much more intricate detail in the maps.**

# %% [markdown]
# - The amount of category combos due to the list format is ridicilus, 10,668 different category tupples to be exact.
# (to approach this problem we could try and concatinate the companies into the larges n categories by count, or use a general funciton or ML Lib to classify)

# %% [markdown]
# - for my dataset I have like 1m unknown places (in the bottom right corner)

# %% [markdown]
# - Use the label feature to put up text data geospacially on the map.

# %% [markdown]
# #TODO figure out how to make the dash togleable with filters and interactable for later on.

# %% [markdown]
# Figure out a way to get to the filters icon on a single sheet. Then right click on it and go to filters and select the category that you wish to filter by. Then from there click the more options arrow to cusomize the filter to your use case. Go back to the option tab on the filter and click on apply to to worksheets and select which worksheets you wish to apply your custom filter too.

# %% [markdown]
# Drag the worksheet into a dashboard then you can go to the down carrot and select filters. then choose the filter you want and how you want it applied. Then in order to style it and put it anywhere that you want change the layout to floating and move it around.

# %% [markdown]
# Include a toggle on the dashboard that allows users to change what kind of business that they want to see: EX: Brand, Non-brand, single local stores **Using Mia's code**

# %% [markdown]
# **Easy:** add a slider for z-score
#
# **Hard:** add a slider for avg rating that is included within the average rating CI on tableau

# %% [markdown]
# For Aiden's code I think we should find a seprarate data set that includes just the long and lat of cities so we can classify something as rural, urban, and suburban. Then we can use the grid code to establish a grid around the cities and see if the long and lat of each individual company fall into that category. From there we can do city comparitive analysis which with be like the **FIRST LAYER IN REVIEW CULTURE**. Remaing layers come from tracking actual shifts in review culture but thats gotta come from aiden's AI slop.

# %%
path = 'Data/simplemaps_uscities_basicv1.93/uscities.csv'

# %% [markdown]
# For Tableau,
#
# 1. lets include a search feature that allows users to search for the speecific sotore that they want.
#
# 2. I also want to make a feature that allows customers to filter the latitude and logitude of their desired area. (implement through )
#
# 3. Look into if the dataset is too large for Tableau
#
# 4. Look into Tableau trial ending
